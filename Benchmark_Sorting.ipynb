# %%
import time
import matplotlib.pyplot as plt
import psutil

def insertion_sort(arr):
    for i in range(1,len(arr)):
        key=arr[i]
        j=i-1
        while j>=0 and arr[j]>key:
            arr[j+1]=arr[j]
            j-=1
        arr[j+1]=key

def selection_sort(arr):
    for i in range(len(arr)):
        min_index=i
        for j in range(i+1,len(arr)):
            if arr[min_index]>arr[j]:
                min_index=j
        arr[i],arr[min_index]=arr[min_index],arr[i]

def bubble_sort(arr):
    for i in range(len(arr)):
        for j in range(0,len(arr)-i-1):
            if arr[j]>arr[j+1]:
                arr[j],arr[j+1]=arr[j+1],arr[j]

def measure_time(algorithm,array_sizes):
    times=[]
    for n in array_sizes:
        array=[random.randint(0,n) for _ in range(n)]
        start=time.time()
        algorithm(array)
        end=time.time()
        times.append(end-start)
    return times

array_sizes=[5,10,20,50,100,200,500,1000,2000,5000]

insertion_times=measure_time(insertion_sort,array_sizes)
selection_times=measure_time(selection_sort,array_sizes)
bubble_times=measure_time(bubble_sort,array_sizes)

plt.plot(array_sizes,insertion_times,label="Insertion Sort")
plt.plot(array_sizes,selection_times,label="Selection Sort")
plt.plot(array_sizes,bubble_times,label="Bubble Sort")
plt.xlabel("Input size (n)")
plt.ylabel("Time (s)")
plt.title("Sorting Algorithms Benchmark")
plt.legend()
plt.show()

system_info = {
    "CPU": psutil.cpu_count(logical=False),
    "RAM": psutil.virtual_memory().total/(1024**3),
}
print(f"System information: {system_info}")
# Out:
# System information: {'CPU': 4, 'RAM': 15.729286193847656}
